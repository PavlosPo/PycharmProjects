# %%
import pandas

# %%
# Ερωτημα 1
data = pandas.read_csv('data.csv')

# %%
# Ερωτημα 2
print(data.tail(5))
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID Country
# 541904  12/9/2011 12:50       0.85     12680.0  France
# 541905  12/9/2011 12:50       2.10     12680.0  France
# 541906  12/9/2011 12:50       4.15     12680.0  France
# 541907  12/9/2011 12:50       4.15     12680.0  France
# 541908  12/9/2011 12:50       4.95     12680.0  France

# %%
# Ερωτημα 3
num_of_columns = len(data.columns)
str_of_columns = " ".join(data.columns.tolist())
print(f'Ο αριθμος των στηλων ειναι: {num_of_columns}', f'\nΚαι οι στηλες ειναι: {str_of_columns}')
# Out:
# Ο αριθμος των στηλων ειναι: 8
# Και οι στηλες ειναι: InvoiceNo StockCode Description Quantity InvoiceDate UnitPrice CustomerID Country

# %%
# Ερωτημα 4
print(data.dtypes)
# Out:
# InvoiceNo       object
# StockCode       object
# Description     object
# Quantity         int64
# InvoiceDate     object
# UnitPrice      float64
# CustomerID     float64
# Country         object
# dtype: object

# %%
# Ερωτημα 5
print(data.isna().any())
# Out:
# InvoiceNo      False
# StockCode      False
# Description     True
# Quantity       False
# InvoiceDate    False
# UnitPrice      False
# CustomerID      True
# Country        False
# dtype: bool

# %%
# Ερωτημα 6
print(f'Υπαρχουν {len(data)} εγραφες.')
# Out:
# Υπαρχουν 541909 εγραφες.

# %%
# Καθαρισμος Dataset

# %%
# Ερωτημα 1
data.dropna(subset=['Description', 'CustomerID'], how='any',inplace=True)

# %%
print(data.count())
# Out:
# InvoiceNo      406829
# StockCode      406829
# Description    406829
# Quantity       406829
# InvoiceDate    406829
# UnitPrice      406829
# CustomerID     406829
# Country        406829
# dtype: int64

# %%
# Ερωτημα 2
to_delete_list = ['AMAZON FEE', 'Manual', 'SAMPLES', 'POSTAGE', 'PACKING CHARGE']
for index_num in data.index:
    if data.at[index_num, 'Description'] in to_delete_list:
        data = data.drop(index_num)

# %%
print(data.count())
# Out:
# InvoiceNo      405152
# StockCode      405152
# Description    405152
# Quantity       405152
# InvoiceDate    405152
# UnitPrice      405152
# CustomerID     405152
# Country        405152
# dtype: int64

# %%
# Ερωτημα 3
data = data.drop(data[data.Quantity < 0].index)

# %%
print(data.count())
# Out:
# InvoiceNo      396521
# StockCode      396521
# Description    396521
# Quantity       396521
# InvoiceDate    396521
# UnitPrice      396521
# CustomerID     396521
# Country        396521
# dtype: int64

# %%
# Ερωτημα 4
quantity_item_total_list = []
for index_num in data.index:
    quantity_item_total_list.append((data.Quantity[index_num] * data.UnitPrice[index_num]).round(2))

# %%
print(data.count())
# Out:
# InvoiceNo      396521
# StockCode      396521
# Description    396521
# Quantity       396521
# InvoiceDate    396521
# UnitPrice      396521
# CustomerID     396521
# Country        396521
# dtype: int64

# %%
data['ItemTotal'] = quantity_item_total_list

# %%
print(data.count())
# Out:
# InvoiceNo      396521
# StockCode      396521
# Description    396521
# Quantity       396521
# InvoiceDate    396521
# UnitPrice      396521
# CustomerID     396521
# Country        396521
# ItemTotal      396521
# dtype: int64

# %%
# Ερωτημα 3.1 
len(data.CustomerID.unique())
# Out:
# 4336

# %%
# Ερωτημα 3.2
print(data.Country.unique())
# Out:
# ['United Kingdom' 'France' 'Australia' 'Netherlands' 'Germany' 'Norway'
#  'EIRE' 'Switzerland' 'Spain' 'Poland' 'Portugal' 'Italy' 'Belgium'
#  'Lithuania' 'Japan' 'Iceland' 'Channel Islands' 'Denmark' 'Cyprus'
#  'Sweden' 'Finland' 'Austria' 'Greece' 'Singapore' 'Lebanon'
#  'United Arab Emirates' 'Israel' 'Saudi Arabia' 'Czech Republic' 'Canada'
#  'Unspecified' 'Brazil' 'USA' 'European Community' 'Bahrain' 'Malta' 'RSA']

# %%
# Ερωτημα 3.3 ???????????????????
items_stock_codes = data[(data.UnitPrice <= 150) & (data.UnitPrice >= 100)].StockCode.unique()
print(items_stock_codes, len((items_stock_codes)))
print(data.columns)
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country', 'ItemTotal'],
#       dtype='object')

# %%
# Ερωτημα 3.4
for s_code in items_stock_codes:
    if s_code not in results:
        print(data[data.StockCode == s_code].Description.unique())
# Out:
# ['RUSTIC  SEVENTEEN DRAWER SIDEBOARD']
# ['VINTAGE RED KITCHEN CABINET']
# ['VINTAGE BLUE KITCHEN CABINET']
# ['CHEST NATURAL WOOD 20 DRAWERS']
# ['CARRIAGE']
# ['REGENCY MIRROR WITH SHUTTERS']

# %%
# Ερωτημα 3.5
data[data.Description.str.contains('HANDBAG', regex=False)] # Add unique method ?
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 989       536520     22583     PACK OF 6 HANDBAG GIFT BOXES         3
# 998       536520     22583     PACK OF 6 HANDBAG GIFT BOXES         1
# 1367      536538     22583     PACK OF 6 HANDBAG GIFT BOXES         2
# 3088      536597     22583     PACK OF 6 HANDBAG GIFT BOXES         2
# 3219      536611    62096A      PINK/YELLOW FLOWERS HANDBAG         6
# 7778      537054    84898F  YELLOW FLOWERS FELT HANDBAG KIT         2
# 8160      537126    84898F  YELLOW FLOWERS FELT HANDBAG KIT         1
# 8166      537128    84898F  YELLOW FLOWERS FELT HANDBAG KIT         1
# 9466      537202    84898F  YELLOW FLOWERS FELT HANDBAG KIT         3
# 17886     537781     22583     PACK OF 6 HANDBAG GIFT BOXES         1
# 19243     537850    62096A      PINK/YELLOW FLOWERS HANDBAG         6
# 28354     538635     22583     PACK OF 6 HANDBAG GIFT BOXES         2
# ...
